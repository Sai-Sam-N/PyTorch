# %% [markdown]
# Reference : https://realpython.com/python-classes/#getting-started-with-python-classes

# %% [markdown]
# Video reference : https://youtu.be/0XR_91AfgZI?si=ppC7SK8P8gH3b7Mp

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Class : Core design
# Object : Modifications of classes
#
# ![image-2.png](attachment:image-2.png)
